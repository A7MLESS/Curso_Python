# %%
df=pd.read_csv("/content/drive/MyDrive/Basura/dataset_part_2.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-256a0ff214be> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/content/drive/MyDrive/Basura/dataset_part_2.csv")
#       2 df
#
# NameError: name 'pd' is not defined
